# %%
#naivebaseys

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/home/root1/pima.csv')

data
# Out:
#     pc_encoded  wbc_encoded  mc_encoded  ast_encoded  bc_encoded  ldh_encoded  \
# 0            6          148          72           35           0         33.6
# 1            1           85          66           29           0         26.6
# 2            8          183          64            0           0         23.3
# 3            1           89          66           23          94         28.1
# 4            0          137          40           35         168         43.1
# ..         ...          ...         ...          ...         ...          ...
# 82           7           83          78           26          71         29.3
# 83           0          101          65           28           0         24.6
# 84           5          137         108            0           0         48.8
# 85           2          110          74           29         125         32.4
# 86          13          106          72           54           0         36.6
#
#    diagnosis
# 0       0.78
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
pc_encoded=le.fit_transform(data['pc_encoded'].values)
wbc_encoded=le.fit_transform(data['wbc_encoded'].values)
mc_encoded=le.fit_transform(data['mc_encoded'].values)
ast_encoded=le.fit_transform(data['ast_encoded'].values)
bc_encoded=le.fit_transform(data['bc_encoded'].values)
ldh_encoded=le.fit_transform(data['ldh_encoded'].values)
Y=le.fit_transform(data['diagnosis'].values)

X=np.array(list(zip(pc_encoded,wbc_encoded,mc_encoded,ast_encoded,bc_encoded,ldh_encoded)))
X
Y
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
model = MultinomialNB()

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

model.fit(X_train, Y_train)
y_pred = model.predict(X_test)

print("Accuracy:",accuracy_score(Y_test, y_pred))

print("\nReport")
print(classification_report(Y_test,y_pred))
# Out:
# Accuracy: 0.078125
#
# Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         1
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         1
# ...
